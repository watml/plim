# %%
# target parameter attack on linear regression with close form solution on the cross derivative

import os
import time
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader
from numpy import linalg as LA
import numpy as np
import math
from tqdm import tqdm
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib
from sklearn.datasets import make_classification


torch.manual_seed(0)
device = 'cuda'

# %%
# creating the gaussian dataset

# define training set
separable = False
while not separable:
    samples = make_classification(n_samples=1000, n_features=3, n_redundant=0, n_informative=1, n_clusters_per_class=1, flip_y=-1)
    red = samples[0][samples[1] == 0]
    blue = samples[0][samples[1] == 1]
    separable = any([red[:, k].max() < blue[:, k].min() or red[:, k].min() > blue[:, k].max() for k in range(2)])
red_labels = np.zeros(len(red))
blue_labels = np.ones(len(blue))

labels = np.append(red_labels,blue_labels)
inputs = np.concatenate((red,blue),axis=0)

X_train, X_test, y_train,  y_test = train_test_split(
    inputs, labels, test_size=0.33, random_state=42)

X_train, X_test = torch.Tensor(X_train),torch.Tensor(X_test)
y_train, y_test = torch.Tensor(y_train),torch.Tensor(y_test)

# %%
batch_size_train= len(X_train)
batch_size_test = len(X_test)
class LinearDataset(Dataset):
    def __init__(self, X, y):
        assert X.size()[0] == y.size()[0]
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.size()[0]

    def __getitem__(self, idx):
        
        
        return [self.X[idx], self.y[idx]]
train_loader = DataLoader(LinearDataset(X_train, y_train), batch_size=batch_size_train, shuffle=False)
test_loader = DataLoader(LinearDataset(X_test, y_test), batch_size=batch_size_test, shuffle=False)

# %%
class LogisticRegression(torch.nn.Module):
    def __init__(self, input_dim, output_dim):
        super(LogisticRegression, self).__init__()
        self.linear = torch.nn.Linear(input_dim, output_dim)
        
    def forward(self, x):
        outputs = torch.sigmoid(self.linear(x))
        return outputs

input_dim = 3 
output_dim = 1 # Two possible outputs
learning_rate = 0.01

model = LogisticRegression(input_dim,output_dim).to(device)
model.load_state_dict(torch.load("gaussian_gd_0.5.pt"))
# Out:
# <All keys matched successfully>

# %%
from scipy.special import lambertw
import math
lambert_w = lambertw(1/math.e)
print(lambert_w)
# Out:
# (0.2784645427610738+0j)

# %%
for param in model.parameters():
    w_p = param
    break
print(w_p/10)
# Out:
# tensor([[-0.0346, -0.2471,  0.0194]], device='cuda:0', grad_fn=<DivBackward0>)

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data)
# Out:
# linear.weight tensor([[-0.3458, -2.4712,  0.1935]], device='cuda:0')
# linear.bias tensor([1.2288], device='cuda:0')

# %%
# try scaling the weights 
state_dict = model.state_dict()
state_dict['linear.weight'] = torch.tensor([[-0.03458,-0.24712,0.01935]])
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
# the script for training target attack
epsilon = 1
lr = 0.005
epochs = 3000

def adjust_learning_rate(lr, epoch):
    """Decay the learning rate based on schedule"""
    lr *= 0.5 * (1. + math.cos(math.pi * epoch / epochs))
    return(lr)


def autograd(outputs, inputs, create_graph=False):
    """Compute gradient of outputs w.r.t. inputs, assuming outputs is a scalar."""
    #inputs = tuple(inputs)
    grads = torch.autograd.grad(outputs, inputs, create_graph=create_graph, allow_unused=True)
    return [xx if xx is not None else yy.new_zeros(yy.size()) for xx, yy in zip(grads, inputs)]

def train(epoch, X,y):
    data, target = X.to(device), y.to(device)
    data.requires_grad=True
    if epoch==0:
        # initialize poisoned data
        data_p = Variable(data[:(int(epsilon*len(data)))])
        target_p = Variable(target[:(int(epsilon*len(target)))])
        torch.save(target_p,'target_p_gaussian_{}.pt'.format(epsilon))
    else:
        data_p = torch.load('data_p_gaussian_{}.pt'.format(epsilon))
        target_p = torch.load('target_p_gaussian_{}.pt'.format(epsilon))
    data_p.requires_grad=True

    # initialize f function
    criterion = torch.nn.BCELoss(reduction='sum')

    # calculate gradient of w on clean sample
    output_c = torch.squeeze(model(data))
    loss_c =  0.5 * criterion(output_c,target)

    # calculate dL/dg_1
    grad_c= autograd(loss_c,tuple(model.parameters()),create_graph=True)
    g1 = grad_c[0]/len(y)

    # calculate the size of epsilon_d w.r.t g1 and the Lambert's W function
    g_mu_dot_w = np.dot(g1.to('cpu').detach().numpy().squeeze(),w_p.cpu().detach().numpy().squeeze())
    if epoch == 0:
        print(g_mu_dot_w)
        print('the necessary size of epsilon_d:{}'.format(g_mu_dot_w/lambert_w))
    

    # calculate gradient of w on poisoned sample
    output_p = torch.squeeze(model(data_p))
    loss_p = 0.5 * criterion(output_p,target_p)
    grad_p= autograd(loss_p,tuple(model.parameters()),create_graph=True)

    g2 = torch.matmul((output_p - target_p).t(),data_p)
    # calculate the true loss: |g_c + g_p|_{2}
    grad_sum = g1+g2
    loss = torch.norm(grad_sum,2)

    update = autograd(loss,data_p,create_graph=True)
    data_t = data_p - lr * update[0]


    data_t = data_t.to('cuda')

    torch.save(data_t, 'data_p_gaussian_{}.pt'.format(epsilon))
    

    print("epoch:{},lr:{},loss:{}".format(epoch,lr,loss))
    
    return loss

# %%
for epoch in range(epochs):
    loss = train(epoch,X_train,y_train)
    if loss<0.0001:
        break
# Out:
# 0.0679838
# the necessary size of epsilon_d:(0.24413807951492283+0j)
# [tensor([[-0.0151,  0.3248, -0.0140],
#         [ 0.0599, -0.8156,  0.0309],
#         [-0.0153,  0.3253, -0.0139],
#         ...,
#         [-0.0143,  0.3290, -0.0143],
#         [ 0.0616, -0.8409,  0.0318],
#         [ 0.0626, -0.8498,  0.0321]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:0,lr:0.005,loss:373.5389404296875
# [tensor([[-0.0151,  0.3247, -0.0139],
#         [ 0.0599, -0.8152,  0.0308],
#         [-0.0154,  0.3251, -0.0139],
#         ...,
#         [-0.0143,  0.3288, -0.0143],
#         [ 0.0617, -0.8406,  0.0318],
#         [ 0.0626, -0.8495,  0.0321]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:1,lr:0.005,loss:372.1507568359375
# [tensor([[-0.0151,  0.3245, -0.0139],
#         [ 0.0599, -0.8149,  0.0308],
#         [-0.0154,  0.3249, -0.0139],
#         ...,
#         [-0.0144,  0.3287, -0.0143],
#         [ 0.0617, -0.8403,  0.0318],
#         [ 0.0627, -0.8492,  0.0321]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2,lr:0.005,loss:370.7635803222656
# [tensor([[-0.0151,  0.3243, -0.0139],
#         [ 0.0600, -0.8146,  0.0308],
#         [-0.0154,  0.3248, -0.0139],
#         ...,
#         [-0.0144,  0.3285, -0.0143],
#         [ 0.0618, -0.8400,  0.0318],
#         [ 0.0627, -0.8489,  0.0320]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:3,lr:0.005,loss:369.3773498535156
# [tensor([[-0.0151,  0.3242, -0.0139],
#         [ 0.0600, -0.8143,  0.0308],
#         [-0.0154,  0.3246, -0.0139],
#         ...,
#         [-0.0144,  0.3283, -0.0143],
#         [ 0.0618, -0.8397,  0.0317],
#         [ 0.0627, -0.8486,  0.0320]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:4,lr:0.005,loss:367.9922180175781
# [tensor([[-0.0152,  0.3240, -0.0139],
#         [ 0.0601, -0.8140,  0.0307],
#         [-0.0154,  0.3244, -0.0139],
#         ...,
#         [-0.0144,  0.3282, -0.0143],
#         [ 0.0618, -0.8394,  0.0317],
#         [ 0.0628, -0.8483,  0.0320]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:5,lr:0.005,loss:366.6080017089844
# [tensor([[-0.0152,  0.3238, -0.0139],
#         [ 0.0601, -0.8137,  0.0307],
#         [-0.0154,  0.3243, -0.0139],
#         ...,
#         [-0.0144,  0.3280, -0.0142],
#         [ 0.0619, -0.8391,  0.0317],
#         [ 0.0628, -0.8480,  0.0320]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:6,lr:0.005,loss:365.2248229980469
# [tensor([[-0.0152,  0.3237, -0.0139],
#         [ 0.0601, -0.8133,  0.0307],
#         [-0.0155,  0.3241, -0.0138],
#         ...,
#         [-0.0144,  0.3278, -0.0142],
#         [ 0.0619, -0.8388,  0.0317],
#         [ 0.0629, -0.8477,  0.0320]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:7,lr:0.005,loss:363.8426513671875
# [tensor([[-0.0152,  0.3235, -0.0139],
#         [ 0.0602, -0.8130,  0.0307],
#         [-0.0155,  0.3239, -0.0138],
#         ...,
#         [-0.0145,  0.3276, -0.0142],
#         [ 0.0620, -0.8385,  0.0317],
#         [ 0.0629, -0.8475,  0.0319]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:8,lr:0.005,loss:362.4614562988281
# [tensor([[-0.0152,  0.3233, -0.0138],
#         [ 0.0602, -0.8127,  0.0306],
#         [-0.0155,  0.3237, -0.0138],
#         ...,
#         [-0.0145,  0.3275, -0.0142],
#         [ 0.0620, -0.8382,  0.0316],
#         [ 0.0629, -0.8472,  0.0319]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:9,lr:0.005,loss:361.081298828125
# [tensor([[-0.0152,  0.3232, -0.0138],
#         [ 0.0603, -0.8124,  0.0306],
#         [-0.0155,  0.3236, -0.0138],
#         ...,
#         [-0.0145,  0.3273, -0.0142],
#         [ 0.0620, -0.8379,  0.0316],
#         [ 0.0630, -0.8469,  0.0319]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:10,lr:0.005,loss:359.7021484375
# [tensor([[-0.0153,  0.3230, -0.0138],
#         [ 0.0603, -0.8121,  0.0306],
#         [-0.0155,  0.3234, -0.0138],
#         ...,
#         [-0.0145,  0.3271, -0.0142],
#         [ 0.0621, -0.8376,  0.0316],
#         [ 0.0630, -0.8466,  0.0319]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:11,lr:0.005,loss:358.323974609375
# [tensor([[-0.0153,  0.3228, -0.0138],
#         [ 0.0603, -0.8118,  0.0306],
#         [-0.0156,  0.3232, -0.0138],
#         ...,
#         [-0.0145,  0.3270, -0.0142],
#         [ 0.0621, -0.8373,  0.0316],
#         [ 0.0631, -0.8463,  0.0318]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:12,lr:0.005,loss:356.94683837890625
# [tensor([[-0.0153,  0.3227, -0.0138],
#         [ 0.0604, -0.8114,  0.0305],
#         [-0.0156,  0.3231, -0.0138],
#         ...,
#         [-0.0145,  0.3268, -0.0142],
#         [ 0.0622, -0.8370,  0.0315],
#         [ 0.0631, -0.8460,  0.0318]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:13,lr:0.005,loss:355.5707092285156
# [tensor([[-0.0153,  0.3225, -0.0138],
#         [ 0.0604, -0.8111,  0.0305],
#         [-0.0156,  0.3229, -0.0138],
#         ...,
#         [-0.0146,  0.3266, -0.0141],
#         [ 0.0622, -0.8367,  0.0315],
#         [ 0.0631, -0.8457,  0.0318]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:14,lr:0.005,loss:354.195556640625
# [tensor([[-0.0153,  0.3223, -0.0138],
#         [ 0.0605, -0.8108,  0.0305],
#         [-0.0156,  0.3227, -0.0137],
#         ...,
#         [-0.0146,  0.3265, -0.0141],
#         [ 0.0622, -0.8364,  0.0315],
#         [ 0.0632, -0.8454,  0.0318]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:15,lr:0.005,loss:352.8214111328125
# [tensor([[-0.0153,  0.3221, -0.0138],
#         [ 0.0605, -0.8105,  0.0305],
#         [-0.0156,  0.3226, -0.0137],
#         ...,
#         [-0.0146,  0.3263, -0.0141],
#         [ 0.0623, -0.8361,  0.0315],
#         [ 0.0632, -0.8451,  0.0318]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:16,lr:0.005,loss:351.4482727050781
# [tensor([[-0.0154,  0.3220, -0.0138],
#         [ 0.0605, -0.8102,  0.0305],
#         [-0.0156,  0.3224, -0.0137],
#         ...,
#         [-0.0146,  0.3261, -0.0141],
#         [ 0.0623, -0.8358,  0.0314],
#         [ 0.0633, -0.8448,  0.0317]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:17,lr:0.005,loss:350.076171875
# [tensor([[-0.0154,  0.3218, -0.0137],
#         [ 0.0606, -0.8098,  0.0304],
#         [-0.0157,  0.3222, -0.0137],
#         ...,
#         [-0.0146,  0.3259, -0.0141],
#         [ 0.0624, -0.8355,  0.0314],
#         [ 0.0633, -0.8445,  0.0317]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:18,lr:0.005,loss:348.7050476074219
# [tensor([[-0.0154,  0.3216, -0.0137],
#         [ 0.0606, -0.8095,  0.0304],
#         [-0.0157,  0.3221, -0.0137],
#         ...,
#         [-0.0147,  0.3258, -0.0141],
#         [ 0.0624, -0.8352,  0.0314],
#         [ 0.0633, -0.8442,  0.0317]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:19,lr:0.005,loss:347.3349304199219
# [tensor([[-0.0154,  0.3215, -0.0137],
#         [ 0.0607, -0.8092,  0.0304],
#         [-0.0157,  0.3219, -0.0137],
#         ...,
#         [-0.0147,  0.3256, -0.0141],
#         [ 0.0624, -0.8349,  0.0314],
#         [ 0.0634, -0.8439,  0.0317]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:20,lr:0.005,loss:345.9658203125
# [tensor([[-0.0154,  0.3213, -0.0137],
#         [ 0.0607, -0.8089,  0.0304],
#         [-0.0157,  0.3217, -0.0137],
#         ...,
#         [-0.0147,  0.3254, -0.0141],
#         [ 0.0625, -0.8346,  0.0314],
#         [ 0.0634, -0.8437,  0.0316]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:21,lr:0.005,loss:344.5977478027344
# [tensor([[-0.0155,  0.3211, -0.0137],
#         [ 0.0607, -0.8086,  0.0303],
#         [-0.0157,  0.3215, -0.0137],
#         ...,
#         [-0.0147,  0.3253, -0.0140],
#         [ 0.0625, -0.8343,  0.0313],
#         [ 0.0635, -0.8434,  0.0316]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:22,lr:0.005,loss:343.2306213378906
# [tensor([[-0.0155,  0.3210, -0.0137],
#         [ 0.0608, -0.8082,  0.0303],
#         [-0.0157,  0.3214, -0.0136],
#         ...,
#         [-0.0147,  0.3251, -0.0140],
#         [ 0.0626, -0.8340,  0.0313],
#         [ 0.0635, -0.8431,  0.0316]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:23,lr:0.005,loss:341.864501953125
# [tensor([[-0.0155,  0.3208, -0.0137],
#         [ 0.0608, -0.8079,  0.0303],
#         [-0.0158,  0.3212, -0.0136],
#         ...,
#         [-0.0147,  0.3249, -0.0140],
#         [ 0.0626, -0.8337,  0.0313],
#         [ 0.0636, -0.8428,  0.0316]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:24,lr:0.005,loss:340.49945068359375
# [tensor([[-0.0155,  0.3206, -0.0137],
#         [ 0.0609, -0.8076,  0.0303],
#         [-0.0158,  0.3210, -0.0136],
#         ...,
#         [-0.0148,  0.3248, -0.0140],
#         [ 0.0626, -0.8334,  0.0313],
#         [ 0.0636, -0.8425,  0.0315]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:25,lr:0.005,loss:339.1353759765625
# [tensor([[-0.0155,  0.3205, -0.0136],
#         [ 0.0609, -0.8073,  0.0302],
#         [-0.0158,  0.3209, -0.0136],
#         ...,
#         [-0.0148,  0.3246, -0.0140],
#         [ 0.0627, -0.8331,  0.0312],
#         [ 0.0636, -0.8422,  0.0315]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:26,lr:0.005,loss:337.77227783203125
# [tensor([[-0.0155,  0.3203, -0.0136],
#         [ 0.0609, -0.8070,  0.0302],
#         [-0.0158,  0.3207, -0.0136],
#         ...,
#         [-0.0148,  0.3244, -0.0140],
#         [ 0.0627, -0.8328,  0.0312],
#         [ 0.0637, -0.8419,  0.0315]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:27,lr:0.005,loss:336.41021728515625
# [tensor([[-0.0156,  0.3201, -0.0136],
#         [ 0.0610, -0.8066,  0.0302],
#         [-0.0158,  0.3205, -0.0136],
#         ...,
#         [-0.0148,  0.3243, -0.0140],
#         [ 0.0628, -0.8325,  0.0312],
#         [ 0.0637, -0.8416,  0.0315]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:28,lr:0.005,loss:335.04913330078125
# [tensor([[-0.0156,  0.3200, -0.0136],
#         [ 0.0610, -0.8063,  0.0302],
#         [-0.0158,  0.3204, -0.0136],
#         ...,
#         [-0.0148,  0.3241, -0.0140],
#         [ 0.0628, -0.8322,  0.0312],
#         [ 0.0638, -0.8413,  0.0315]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:29,lr:0.005,loss:333.6890869140625
# [tensor([[-0.0156,  0.3198, -0.0136],
#         [ 0.0611, -0.8060,  0.0301],
#         [-0.0159,  0.3202, -0.0136],
#         ...,
#         [-0.0148,  0.3239, -0.0140],
#         [ 0.0628, -0.8319,  0.0311],
#         [ 0.0638, -0.8410,  0.0314]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:30,lr:0.005,loss:332.3299865722656
# [tensor([[-0.0156,  0.3196, -0.0136],
#         [ 0.0611, -0.8057,  0.0301],
#         [-0.0159,  0.3200, -0.0136],
#         ...,
#         [-0.0149,  0.3238, -0.0139],
#         [ 0.0629, -0.8316,  0.0311],
#         [ 0.0638, -0.8407,  0.0314]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:31,lr:0.005,loss:330.97198486328125
# [tensor([[-0.0156,  0.3195, -0.0136],
#         [ 0.0611, -0.8054,  0.0301],
#         [-0.0159,  0.3199, -0.0135],
#         ...,
#         [-0.0149,  0.3236, -0.0139],
#         [ 0.0629, -0.8313,  0.0311],
#         [ 0.0639, -0.8404,  0.0314]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:32,lr:0.005,loss:329.61492919921875
# [tensor([[-0.0156,  0.3193, -0.0136],
#         [ 0.0612, -0.8050,  0.0301],
#         [-0.0159,  0.3197, -0.0135],
#         ...,
#         [-0.0149,  0.3234, -0.0139],
#         [ 0.0630, -0.8310,  0.0311],
#         [ 0.0639, -0.8401,  0.0314]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:33,lr:0.005,loss:328.2588806152344
# [tensor([[-0.0157,  0.3191, -0.0136],
#         [ 0.0612, -0.8047,  0.0300],
#         [-0.0159,  0.3195, -0.0135],
#         ...,
#         [-0.0149,  0.3233, -0.0139],
#         [ 0.0630, -0.8307,  0.0310],
#         [ 0.0640, -0.8398,  0.0313]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:34,lr:0.005,loss:326.9038391113281
# [tensor([[-0.0157,  0.3190, -0.0135],
#         [ 0.0613, -0.8044,  0.0300],
#         [-0.0159,  0.3194, -0.0135],
#         ...,
#         [-0.0149,  0.3231, -0.0139],
#         [ 0.0631, -0.8304,  0.0310],
#         [ 0.0640, -0.8395,  0.0313]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:35,lr:0.005,loss:325.5498352050781
# [tensor([[-0.0157,  0.3188, -0.0135],
#         [ 0.0613, -0.8041,  0.0300],
#         [-0.0160,  0.3192, -0.0135],
#         ...,
#         [-0.0149,  0.3229, -0.0139],
#         [ 0.0631, -0.8301,  0.0310],
#         [ 0.0641, -0.8392,  0.0313]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:36,lr:0.005,loss:324.1968078613281
# [tensor([[-0.0157,  0.3186, -0.0135],
#         [ 0.0613, -0.8037,  0.0300],
#         [-0.0160,  0.3190, -0.0135],
#         ...,
#         [-0.0150,  0.3228, -0.0139],
#         [ 0.0631, -0.8298,  0.0310],
#         [ 0.0641, -0.8389,  0.0313]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:37,lr:0.005,loss:322.84478759765625
# [tensor([[-0.0157,  0.3185, -0.0135],
#         [ 0.0614, -0.8034,  0.0299],
#         [-0.0160,  0.3189, -0.0135],
#         ...,
#         [-0.0150,  0.3226, -0.0139],
#         [ 0.0632, -0.8295,  0.0310],
#         [ 0.0641, -0.8386,  0.0312]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:38,lr:0.005,loss:321.4938049316406
# [tensor([[-0.0157,  0.3183, -0.0135],
#         [ 0.0614, -0.8031,  0.0299],
#         [-0.0160,  0.3187, -0.0135],
#         ...,
#         [-0.0150,  0.3224, -0.0138],
#         [ 0.0632, -0.8292,  0.0309],
#         [ 0.0642, -0.8383,  0.0312]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:39,lr:0.005,loss:320.143798828125
# [tensor([[-0.0158,  0.3182, -0.0135],
#         [ 0.0615, -0.8028,  0.0299],
#         [-0.0160,  0.3185, -0.0134],
#         ...,
#         [-0.0150,  0.3223, -0.0138],
#         [ 0.0633, -0.8289,  0.0309],
#         [ 0.0642, -0.8380,  0.0312]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:40,lr:0.005,loss:318.7948303222656
# [tensor([[-0.0158,  0.3180, -0.0135],
#         [ 0.0615, -0.8025,  0.0299],
#         [-0.0161,  0.3184, -0.0134],
#         ...,
#         [-0.0150,  0.3221, -0.0138],
#         [ 0.0633, -0.8286,  0.0309],
#         [ 0.0643, -0.8377,  0.0312]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:41,lr:0.005,loss:317.4468078613281
# [tensor([[-0.0158,  0.3178, -0.0135],
#         [ 0.0615, -0.8021,  0.0299],
#         [-0.0161,  0.3182, -0.0134],
#         ...,
#         [-0.0150,  0.3219, -0.0138],
#         [ 0.0633, -0.8282,  0.0309],
#         [ 0.0643, -0.8374,  0.0312]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:42,lr:0.005,loss:316.09979248046875
# [tensor([[-0.0158,  0.3177, -0.0134],
#         [ 0.0616, -0.8018,  0.0298],
#         [-0.0161,  0.3180, -0.0134],
#         ...,
#         [-0.0151,  0.3218, -0.0138],
#         [ 0.0634, -0.8279,  0.0308],
#         [ 0.0643, -0.8371,  0.0311]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:43,lr:0.005,loss:314.75384521484375
# [tensor([[-0.0158,  0.3175, -0.0134],
#         [ 0.0616, -0.8015,  0.0298],
#         [-0.0161,  0.3179, -0.0134],
#         ...,
#         [-0.0151,  0.3216, -0.0138],
#         [ 0.0634, -0.8276,  0.0308],
#         [ 0.0644, -0.8368,  0.0311]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:44,lr:0.005,loss:313.40887451171875
# [tensor([[-0.0158,  0.3173, -0.0134],
#         [ 0.0617, -0.8012,  0.0298],
#         [-0.0161,  0.3177, -0.0134],
#         ...,
#         [-0.0151,  0.3214, -0.0138],
#         [ 0.0635, -0.8273,  0.0308],
#         [ 0.0644, -0.8365,  0.0311]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:45,lr:0.005,loss:312.0649108886719
# [tensor([[-0.0159,  0.3172, -0.0134],
#         [ 0.0617, -0.8008,  0.0298],
#         [-0.0161,  0.3175, -0.0134],
#         ...,
#         [-0.0151,  0.3213, -0.0138],
#         [ 0.0635, -0.8270,  0.0308],
#         [ 0.0645, -0.8362,  0.0311]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:46,lr:0.005,loss:310.7218933105469
# [tensor([[-0.0159,  0.3170, -0.0134],
#         [ 0.0617, -0.8005,  0.0297],
#         [-0.0162,  0.3174, -0.0134],
#         ...,
#         [-0.0151,  0.3211, -0.0138],
#         [ 0.0635, -0.8267,  0.0307],
#         [ 0.0645, -0.8360,  0.0310]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:47,lr:0.005,loss:309.3799743652344
# [tensor([[-0.0159,  0.3168, -0.0134],
#         [ 0.0618, -0.8002,  0.0297],
#         [-0.0162,  0.3172, -0.0134],
#         ...,
#         [-0.0152,  0.3209, -0.0137],
#         [ 0.0636, -0.8264,  0.0307],
#         [ 0.0646, -0.8357,  0.0310]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:48,lr:0.005,loss:308.0390319824219
# [tensor([[-0.0159,  0.3167, -0.0134],
#         [ 0.0618, -0.7999,  0.0297],
#         [-0.0162,  0.3171, -0.0133],
#         ...,
#         [-0.0152,  0.3208, -0.0137],
#         [ 0.0636, -0.8261,  0.0307],
#         [ 0.0646, -0.8354,  0.0310]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:49,lr:0.005,loss:306.69903564453125
# [tensor([[-0.0159,  0.3165, -0.0134],
#         [ 0.0619, -0.7995,  0.0297],
#         [-0.0162,  0.3169, -0.0133],
#         ...,
#         [-0.0152,  0.3206, -0.0137],
#         [ 0.0637, -0.8258,  0.0307],
#         [ 0.0646, -0.8351,  0.0310]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:50,lr:0.005,loss:305.3601379394531
# [tensor([[-0.0159,  0.3163, -0.0134],
#         [ 0.0619, -0.7992,  0.0296],
#         [-0.0162,  0.3167, -0.0133],
#         ...,
#         [-0.0152,  0.3204, -0.0137],
#         [ 0.0637, -0.8255,  0.0307],
#         [ 0.0647, -0.8348,  0.0309]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:51,lr:0.005,loss:304.0221862792969
# [tensor([[-0.0160,  0.3162, -0.0133],
#         [ 0.0620, -0.7989,  0.0296],
#         [-0.0162,  0.3166, -0.0133],
#         ...,
#         [-0.0152,  0.3203, -0.0137],
#         [ 0.0638, -0.8252,  0.0306],
#         [ 0.0647, -0.8345,  0.0309]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:52,lr:0.005,loss:302.685302734375
# [tensor([[-0.0160,  0.3160, -0.0133],
#         [ 0.0620, -0.7986,  0.0296],
#         [-0.0163,  0.3164, -0.0133],
#         ...,
#         [-0.0152,  0.3201, -0.0137],
#         [ 0.0638, -0.8249,  0.0306],
#         [ 0.0648, -0.8342,  0.0309]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:53,lr:0.005,loss:301.3493347167969
# [tensor([[-0.0160,  0.3159, -0.0133],
#         [ 0.0620, -0.7982,  0.0296],
#         [-0.0163,  0.3162, -0.0133],
#         ...,
#         [-0.0153,  0.3199, -0.0137],
#         [ 0.0638, -0.8246,  0.0306],
#         [ 0.0648, -0.8339,  0.0309]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:54,lr:0.005,loss:300.0144348144531
# [tensor([[-0.0160,  0.3157, -0.0133],
#         [ 0.0621, -0.7979,  0.0295],
#         [-0.0163,  0.3161, -0.0133],
#         ...,
#         [-0.0153,  0.3198, -0.0137],
#         [ 0.0639, -0.8243,  0.0306],
#         [ 0.0648, -0.8336,  0.0309]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:55,lr:0.005,loss:298.6805419921875
# [tensor([[-0.0160,  0.3155, -0.0133],
#         [ 0.0621, -0.7976,  0.0295],
#         [-0.0163,  0.3159, -0.0133],
#         ...,
#         [-0.0153,  0.3196, -0.0136],
#         [ 0.0639, -0.8239,  0.0305],
#         [ 0.0649, -0.8333,  0.0308]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:56,lr:0.005,loss:297.3476257324219
# [tensor([[-0.0161,  0.3154, -0.0133],
#         [ 0.0622, -0.7973,  0.0295],
#         [-0.0163,  0.3157, -0.0132],
#         ...,
#         [-0.0153,  0.3194, -0.0136],
#         [ 0.0640, -0.8236,  0.0305],
#         [ 0.0649, -0.8330,  0.0308]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:57,lr:0.005,loss:296.0157165527344
# [tensor([[-0.0161,  0.3152, -0.0133],
#         [ 0.0622, -0.7969,  0.0295],
#         [-0.0163,  0.3156, -0.0132],
#         ...,
#         [-0.0153,  0.3193, -0.0136],
#         [ 0.0640, -0.8233,  0.0305],
#         [ 0.0650, -0.8326,  0.0308]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:58,lr:0.005,loss:294.6848449707031
# [tensor([[-0.0161,  0.3150, -0.0133],
#         [ 0.0622, -0.7966,  0.0294],
#         [-0.0164,  0.3154, -0.0132],
#         ...,
#         [-0.0153,  0.3191, -0.0136],
#         [ 0.0640, -0.8230,  0.0305],
#         [ 0.0650, -0.8323,  0.0308]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:59,lr:0.005,loss:293.3549499511719
# [tensor([[-0.0161,  0.3149, -0.0132],
#         [ 0.0623, -0.7963,  0.0294],
#         [-0.0164,  0.3153, -0.0132],
#         ...,
#         [-0.0154,  0.3190, -0.0136],
#         [ 0.0641, -0.8227,  0.0304],
#         [ 0.0651, -0.8320,  0.0307]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:60,lr:0.005,loss:292.0260925292969
# [tensor([[-0.0161,  0.3147, -0.0132],
#         [ 0.0623, -0.7960,  0.0294],
#         [-0.0164,  0.3151, -0.0132],
#         ...,
#         [-0.0154,  0.3188, -0.0136],
#         [ 0.0641, -0.8224,  0.0304],
#         [ 0.0651, -0.8317,  0.0307]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:61,lr:0.005,loss:290.6982116699219
# [tensor([[-0.0161,  0.3146, -0.0132],
#         [ 0.0624, -0.7956,  0.0294],
#         [-0.0164,  0.3149, -0.0132],
#         ...,
#         [-0.0154,  0.3186, -0.0136],
#         [ 0.0642, -0.8221,  0.0304],
#         [ 0.0651, -0.8314,  0.0307]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:62,lr:0.005,loss:289.371337890625
# [tensor([[-0.0162,  0.3144, -0.0132],
#         [ 0.0624, -0.7953,  0.0293],
#         [-0.0164,  0.3148, -0.0132],
#         ...,
#         [-0.0154,  0.3185, -0.0136],
#         [ 0.0642, -0.8218,  0.0304],
#         [ 0.0652, -0.8311,  0.0307]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:63,lr:0.005,loss:288.0454406738281
# [tensor([[-0.0162,  0.3142, -0.0132],
#         [ 0.0624, -0.7950,  0.0293],
#         [-0.0164,  0.3146, -0.0132],
#         ...,
#         [-0.0154,  0.3183, -0.0136],
#         [ 0.0643, -0.8215,  0.0303],
#         [ 0.0652, -0.8308,  0.0306]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:64,lr:0.005,loss:286.7206115722656
# [tensor([[-0.0162,  0.3141, -0.0132],
#         [ 0.0625, -0.7947,  0.0293],
#         [-0.0165,  0.3144, -0.0132],
#         ...,
#         [-0.0154,  0.3181, -0.0135],
#         [ 0.0643, -0.8212,  0.0303],
#         [ 0.0653, -0.8305,  0.0306]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:65,lr:0.005,loss:285.3967590332031
# [tensor([[-0.0162,  0.3139, -0.0132],
#         [ 0.0625, -0.7943,  0.0293],
#         [-0.0165,  0.3143, -0.0131],
#         ...,
#         [-0.0155,  0.3180, -0.0135],
#         [ 0.0643, -0.8209,  0.0303],
#         [ 0.0653, -0.8302,  0.0306]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:66,lr:0.005,loss:284.0738830566406
# [tensor([[-0.0162,  0.3138, -0.0132],
#         [ 0.0626, -0.7940,  0.0292],
#         [-0.0165,  0.3141, -0.0131],
#         ...,
#         [-0.0155,  0.3178, -0.0135],
#         [ 0.0644, -0.8205,  0.0303],
#         [ 0.0653, -0.8299,  0.0306]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:67,lr:0.005,loss:282.7520446777344
# [tensor([[-0.0162,  0.3136, -0.0132],
#         [ 0.0626, -0.7937,  0.0292],
#         [-0.0165,  0.3139, -0.0131],
#         ...,
#         [-0.0155,  0.3176, -0.0135],
#         [ 0.0644, -0.8202,  0.0302],
#         [ 0.0654, -0.8296,  0.0306]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:68,lr:0.005,loss:281.4312438964844
# [tensor([[-0.0163,  0.3134, -0.0131],
#         [ 0.0626, -0.7934,  0.0292],
#         [-0.0165,  0.3138, -0.0131],
#         ...,
#         [-0.0155,  0.3175, -0.0135],
#         [ 0.0645, -0.8199,  0.0302],
#         [ 0.0654, -0.8293,  0.0305]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:69,lr:0.005,loss:280.11138916015625
# [tensor([[-0.0163,  0.3133, -0.0131],
#         [ 0.0627, -0.7930,  0.0292],
#         [-0.0165,  0.3136, -0.0131],
#         ...,
#         [-0.0155,  0.3173, -0.0135],
#         [ 0.0645, -0.8196,  0.0302],
#         [ 0.0655, -0.8290,  0.0305]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:70,lr:0.005,loss:278.7925720214844
# [tensor([[-0.0163,  0.3131, -0.0131],
#         [ 0.0627, -0.7927,  0.0291],
#         [-0.0166,  0.3135, -0.0131],
#         ...,
#         [-0.0155,  0.3172, -0.0135],
#         [ 0.0645, -0.8193,  0.0302],
#         [ 0.0655, -0.8287,  0.0305]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:71,lr:0.005,loss:277.4747619628906
# [tensor([[-0.0163,  0.3129, -0.0131],
#         [ 0.0628, -0.7924,  0.0291],
#         [-0.0166,  0.3133, -0.0131],
#         ...,
#         [-0.0156,  0.3170, -0.0135],
#         [ 0.0646, -0.8190,  0.0302],
#         [ 0.0656, -0.8284,  0.0305]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:72,lr:0.005,loss:276.157958984375
# [tensor([[-0.0163,  0.3128, -0.0131],
#         [ 0.0628, -0.7920,  0.0291],
#         [-0.0166,  0.3131, -0.0131],
#         ...,
#         [-0.0156,  0.3168, -0.0135],
#         [ 0.0646, -0.8187,  0.0301],
#         [ 0.0656, -0.8281,  0.0304]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:73,lr:0.005,loss:274.8421325683594
# [tensor([[-0.0163,  0.3126, -0.0131],
#         [ 0.0628, -0.7917,  0.0291],
#         [-0.0166,  0.3130, -0.0131],
#         ...,
#         [-0.0156,  0.3167, -0.0134],
#         [ 0.0647, -0.8184,  0.0301],
#         [ 0.0656, -0.8278,  0.0304]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:74,lr:0.005,loss:273.5273742675781
# [tensor([[-0.0164,  0.3125, -0.0131],
#         [ 0.0629, -0.7914,  0.0290],
#         [-0.0166,  0.3128, -0.0130],
#         ...,
#         [-0.0156,  0.3165, -0.0134],
#         [ 0.0647, -0.8181,  0.0301],
#         [ 0.0657, -0.8275,  0.0304]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:75,lr:0.005,loss:272.21356201171875
# [tensor([[-0.0164,  0.3123, -0.0131],
#         [ 0.0629, -0.7911,  0.0290],
#         [-0.0166,  0.3127, -0.0130],
#         ...,
#         [-0.0156,  0.3163, -0.0134],
#         [ 0.0648, -0.8177,  0.0301],
#         [ 0.0657, -0.8272,  0.0304]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:76,lr:0.005,loss:270.9007873535156
# [tensor([[-0.0164,  0.3121, -0.0131],
#         [ 0.0630, -0.7907,  0.0290],
#         [-0.0167,  0.3125, -0.0130],
#         ...,
#         [-0.0156,  0.3162, -0.0134],
#         [ 0.0648, -0.8174,  0.0300],
#         [ 0.0658, -0.8269,  0.0303]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:77,lr:0.005,loss:269.5889892578125
# [tensor([[-0.0164,  0.3120, -0.0130],
#         [ 0.0630, -0.7904,  0.0290],
#         [-0.0167,  0.3123, -0.0130],
#         ...,
#         [-0.0157,  0.3160, -0.0134],
#         [ 0.0648, -0.8171,  0.0300],
#         [ 0.0658, -0.8266,  0.0303]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:78,lr:0.005,loss:268.2781677246094
# [tensor([[-0.0164,  0.3118, -0.0130],
#         [ 0.0631, -0.7901,  0.0290],
#         [-0.0167,  0.3122, -0.0130],
#         ...,
#         [-0.0157,  0.3159, -0.0134],
#         [ 0.0649, -0.8168,  0.0300],
#         [ 0.0658, -0.8263,  0.0303]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:79,lr:0.005,loss:266.9684143066406
# [tensor([[-0.0164,  0.3117, -0.0130],
#         [ 0.0631, -0.7898,  0.0289],
#         [-0.0167,  0.3120, -0.0130],
#         ...,
#         [-0.0157,  0.3157, -0.0134],
#         [ 0.0649, -0.8165,  0.0300],
#         [ 0.0659, -0.8260,  0.0303]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:80,lr:0.005,loss:265.65966796875
# [tensor([[-0.0165,  0.3115, -0.0130],
#         [ 0.0631, -0.7894,  0.0289],
#         [-0.0167,  0.3118, -0.0130],
#         ...,
#         [-0.0157,  0.3155, -0.0134],
#         [ 0.0650, -0.8162,  0.0299],
#         [ 0.0659, -0.8257,  0.0302]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:81,lr:0.005,loss:264.3518981933594
# [tensor([[-0.0165,  0.3113, -0.0130],
#         [ 0.0632, -0.7891,  0.0289],
#         [-0.0167,  0.3117, -0.0130],
#         ...,
#         [-0.0157,  0.3154, -0.0133],
#         [ 0.0650, -0.8159,  0.0299],
#         [ 0.0660, -0.8254,  0.0302]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:82,lr:0.005,loss:263.0451354980469
# [tensor([[-0.0165,  0.3112, -0.0130],
#         [ 0.0632, -0.7888,  0.0289],
#         [-0.0168,  0.3115, -0.0130],
#         ...,
#         [-0.0157,  0.3152, -0.0133],
#         [ 0.0650, -0.8156,  0.0299],
#         [ 0.0660, -0.8251,  0.0302]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:83,lr:0.005,loss:261.7393798828125
# [tensor([[-0.0165,  0.3110, -0.0130],
#         [ 0.0633, -0.7884,  0.0288],
#         [-0.0168,  0.3114, -0.0129],
#         ...,
#         [-0.0158,  0.3151, -0.0133],
#         [ 0.0651, -0.8152,  0.0299],
#         [ 0.0661, -0.8248,  0.0302]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:84,lr:0.005,loss:260.43463134765625
# [tensor([[-0.0165,  0.3109, -0.0130],
#         [ 0.0633, -0.7881,  0.0288],
#         [-0.0168,  0.3112, -0.0129],
#         ...,
#         [-0.0158,  0.3149, -0.0133],
#         [ 0.0651, -0.8149,  0.0298],
#         [ 0.0661, -0.8244,  0.0302]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:85,lr:0.005,loss:259.1308898925781
# [tensor([[-0.0165,  0.3107, -0.0130],
#         [ 0.0633, -0.7878,  0.0288],
#         [-0.0168,  0.3110, -0.0129],
#         ...,
#         [-0.0158,  0.3147, -0.0133],
#         [ 0.0652, -0.8146,  0.0298],
#         [ 0.0661, -0.8241,  0.0301]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:86,lr:0.005,loss:257.8281555175781
# [tensor([[-0.0166,  0.3105, -0.0129],
#         [ 0.0634, -0.7875,  0.0288],
#         [-0.0168,  0.3109, -0.0129],
#         ...,
#         [-0.0158,  0.3146, -0.0133],
#         [ 0.0652, -0.8143,  0.0298],
#         [ 0.0662, -0.8238,  0.0301]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:87,lr:0.005,loss:256.52642822265625
# [tensor([[-0.0166,  0.3104, -0.0129],
#         [ 0.0634, -0.7871,  0.0287],
#         [-0.0169,  0.3107, -0.0129],
#         ...,
#         [-0.0158,  0.3144, -0.0133],
#         [ 0.0653, -0.8140,  0.0298],
#         [ 0.0662, -0.8235,  0.0301]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:88,lr:0.005,loss:255.22572326660156
# [tensor([[-0.0166,  0.3102, -0.0129],
#         [ 0.0635, -0.7868,  0.0287],
#         [-0.0169,  0.3106, -0.0129],
#         ...,
#         [-0.0158,  0.3142, -0.0133],
#         [ 0.0653, -0.8137,  0.0297],
#         [ 0.0663, -0.8232,  0.0301]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:89,lr:0.005,loss:253.92601013183594
# [tensor([[-0.0166,  0.3101, -0.0129],
#         [ 0.0635, -0.7865,  0.0287],
#         [-0.0169,  0.3104, -0.0129],
#         ...,
#         [-0.0159,  0.3141, -0.0133],
#         [ 0.0653, -0.8134,  0.0297],
#         [ 0.0663, -0.8229,  0.0300]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:90,lr:0.005,loss:252.62728881835938
# [tensor([[-0.0166,  0.3099, -0.0129],
#         [ 0.0635, -0.7861,  0.0287],
#         [-0.0169,  0.3102, -0.0129],
#         ...,
#         [-0.0159,  0.3139, -0.0132],
#         [ 0.0654, -0.8130,  0.0297],
#         [ 0.0664, -0.8226,  0.0300]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:91,lr:0.005,loss:251.32958984375
# [tensor([[-0.0166,  0.3098, -0.0129],
#         [ 0.0636, -0.7858,  0.0286],
#         [-0.0169,  0.3101, -0.0128],
#         ...,
#         [-0.0159,  0.3138, -0.0132],
#         [ 0.0654, -0.8127,  0.0297],
#         [ 0.0664, -0.8223,  0.0300]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:92,lr:0.005,loss:250.03286743164062
# [tensor([[-0.0167,  0.3096, -0.0129],
#         [ 0.0636, -0.7855,  0.0286],
#         [-0.0169,  0.3099, -0.0128],
#         ...,
#         [-0.0159,  0.3136, -0.0132],
#         [ 0.0655, -0.8124,  0.0297],
#         [ 0.0664, -0.8220,  0.0300]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:93,lr:0.005,loss:248.7371826171875
# [tensor([[-0.0167,  0.3094, -0.0129],
#         [ 0.0637, -0.7851,  0.0286],
#         [-0.0170,  0.3098, -0.0128],
#         ...,
#         [-0.0159,  0.3134, -0.0132],
#         [ 0.0655, -0.8121,  0.0296],
#         [ 0.0665, -0.8217,  0.0299]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:94,lr:0.005,loss:247.44248962402344
# [tensor([[-0.0167,  0.3093, -0.0128],
#         [ 0.0637, -0.7848,  0.0286],
#         [-0.0170,  0.3096, -0.0128],
#         ...,
#         [-0.0159,  0.3133, -0.0132],
#         [ 0.0655, -0.8118,  0.0296],
#         [ 0.0665, -0.8214,  0.0299]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:95,lr:0.005,loss:246.1488037109375
# [tensor([[-0.0167,  0.3091, -0.0128],
#         [ 0.0637, -0.7845,  0.0285],
#         [-0.0170,  0.3095, -0.0128],
#         ...,
#         [-0.0160,  0.3131, -0.0132],
#         [ 0.0656, -0.8115,  0.0296],
#         [ 0.0666, -0.8211,  0.0299]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:96,lr:0.005,loss:244.85609436035156
# [tensor([[-0.0167,  0.3090, -0.0128],
#         [ 0.0638, -0.7842,  0.0285],
#         [-0.0170,  0.3093, -0.0128],
#         ...,
#         [-0.0160,  0.3130, -0.0132],
#         [ 0.0656, -0.8112,  0.0296],
#         [ 0.0666, -0.8208,  0.0299]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:97,lr:0.005,loss:243.56443786621094
# [tensor([[-0.0167,  0.3088, -0.0128],
#         [ 0.0638, -0.7838,  0.0285],
#         [-0.0170,  0.3091, -0.0128],
#         ...,
#         [-0.0160,  0.3128, -0.0132],
#         [ 0.0657, -0.8108,  0.0295],
#         [ 0.0667, -0.8204,  0.0298]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:98,lr:0.005,loss:242.27377319335938
# [tensor([[-0.0168,  0.3086, -0.0128],
#         [ 0.0639, -0.7835,  0.0285],
#         [-0.0170,  0.3090, -0.0128],
#         ...,
#         [-0.0160,  0.3127, -0.0132],
#         [ 0.0657, -0.8105,  0.0295],
#         [ 0.0667, -0.8201,  0.0298]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:99,lr:0.005,loss:240.98410034179688
# [tensor([[-0.0168,  0.3085, -0.0128],
#         [ 0.0639, -0.7832,  0.0284],
#         [-0.0171,  0.3088, -0.0128],
#         ...,
#         [-0.0160,  0.3125, -0.0131],
#         [ 0.0658, -0.8102,  0.0295],
#         [ 0.0667, -0.8198,  0.0298]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:100,lr:0.005,loss:239.69541931152344
# [tensor([[-0.0168,  0.3083, -0.0128],
#         [ 0.0640, -0.7828,  0.0284],
#         [-0.0171,  0.3087, -0.0127],
#         ...,
#         [-0.0160,  0.3123, -0.0131],
#         [ 0.0658, -0.8099,  0.0295],
#         [ 0.0668, -0.8195,  0.0298]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:101,lr:0.005,loss:238.40774536132812
# [tensor([[-0.0168,  0.3082, -0.0128],
#         [ 0.0640, -0.7825,  0.0284],
#         [-0.0171,  0.3085, -0.0127],
#         ...,
#         [-0.0161,  0.3122, -0.0131],
#         [ 0.0658, -0.8096,  0.0294],
#         [ 0.0668, -0.8192,  0.0298]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:102,lr:0.005,loss:237.12110900878906
# [tensor([[-0.0168,  0.3080, -0.0128],
#         [ 0.0640, -0.7822,  0.0284],
#         [-0.0171,  0.3083, -0.0127],
#         ...,
#         [-0.0161,  0.3120, -0.0131],
#         [ 0.0659, -0.8093,  0.0294],
#         [ 0.0669, -0.8189,  0.0297]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:103,lr:0.005,loss:235.83543395996094
# [tensor([[-0.0168,  0.3079, -0.0127],
#         [ 0.0641, -0.7818,  0.0283],
#         [-0.0171,  0.3082, -0.0127],
#         ...,
#         [-0.0161,  0.3119, -0.0131],
#         [ 0.0659, -0.8089,  0.0294],
#         [ 0.0669, -0.8186,  0.0297]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:104,lr:0.005,loss:234.55076599121094
# [tensor([[-0.0169,  0.3077, -0.0127],
#         [ 0.0641, -0.7815,  0.0283],
#         [-0.0171,  0.3080, -0.0127],
#         ...,
#         [-0.0161,  0.3117, -0.0131],
#         [ 0.0660, -0.8086,  0.0294],
#         [ 0.0669, -0.8183,  0.0297]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:105,lr:0.005,loss:233.26715087890625
# [tensor([[-0.0169,  0.3075, -0.0127],
#         [ 0.0642, -0.7812,  0.0283],
#         [-0.0172,  0.3079, -0.0127],
#         ...,
#         [-0.0161,  0.3115, -0.0131],
#         [ 0.0660, -0.8083,  0.0293],
#         [ 0.0670, -0.8180,  0.0297]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:106,lr:0.005,loss:231.9844970703125
# [tensor([[-0.0169,  0.3074, -0.0127],
#         [ 0.0642, -0.7808,  0.0283],
#         [-0.0172,  0.3077, -0.0127],
#         ...,
#         [-0.0161,  0.3114, -0.0131],
#         [ 0.0660, -0.8080,  0.0293],
#         [ 0.0670, -0.8177,  0.0296]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:107,lr:0.005,loss:230.702880859375
# [tensor([[-0.0169,  0.3072, -0.0127],
#         [ 0.0642, -0.7805,  0.0282],
#         [-0.0172,  0.3076, -0.0127],
#         ...,
#         [-0.0162,  0.3112, -0.0131],
#         [ 0.0661, -0.8077,  0.0293],
#         [ 0.0671, -0.8174,  0.0296]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:108,lr:0.005,loss:229.4222412109375
# [tensor([[-0.0169,  0.3071, -0.0127],
#         [ 0.0643, -0.7802,  0.0282],
#         [-0.0172,  0.3074, -0.0127],
#         ...,
#         [-0.0162,  0.3111, -0.0130],
#         [ 0.0661, -0.8074,  0.0293],
#         [ 0.0671, -0.8170,  0.0296]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:109,lr:0.005,loss:228.14260864257812
# [tensor([[-0.0169,  0.3069, -0.0127],
#         [ 0.0643, -0.7798,  0.0282],
#         [-0.0172,  0.3072, -0.0126],
#         ...,
#         [-0.0162,  0.3109, -0.0130],
#         [ 0.0662, -0.8070,  0.0292],
#         [ 0.0672, -0.8167,  0.0296]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:110,lr:0.005,loss:226.8639678955078
# [tensor([[-0.0170,  0.3068, -0.0127],
#         [ 0.0644, -0.7795,  0.0282],
#         [-0.0172,  0.3071, -0.0126],
#         ...,
#         [-0.0162,  0.3107, -0.0130],
#         [ 0.0662, -0.8067,  0.0292],
#         [ 0.0672, -0.8164,  0.0295]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:111,lr:0.005,loss:225.58633422851562
# [tensor([[-0.0170,  0.3066, -0.0127],
#         [ 0.0644, -0.7792,  0.0281],
#         [-0.0173,  0.3069, -0.0126],
#         ...,
#         [-0.0162,  0.3106, -0.0130],
#         [ 0.0663, -0.8064,  0.0292],
#         [ 0.0672, -0.8161,  0.0295]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:112,lr:0.005,loss:224.3097381591797
# [tensor([[-0.0170,  0.3064, -0.0126],
#         [ 0.0644, -0.7788,  0.0281],
#         [-0.0173,  0.3068, -0.0126],
#         ...,
#         [-0.0162,  0.3104, -0.0130],
#         [ 0.0663, -0.8061,  0.0292],
#         [ 0.0673, -0.8158,  0.0295]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:113,lr:0.005,loss:223.0341339111328
# [tensor([[-0.0170,  0.3063, -0.0126],
#         [ 0.0645, -0.7785,  0.0281],
#         [-0.0173,  0.3066, -0.0126],
#         ...,
#         [-0.0163,  0.3103, -0.0130],
#         [ 0.0663, -0.8058,  0.0291],
#         [ 0.0673, -0.8155,  0.0295]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:114,lr:0.005,loss:221.75950622558594
# [tensor([[-0.0170,  0.3061, -0.0126],
#         [ 0.0645, -0.7782,  0.0281],
#         [-0.0173,  0.3065, -0.0126],
#         ...,
#         [-0.0163,  0.3101, -0.0130],
#         [ 0.0664, -0.8054,  0.0291],
#         [ 0.0674, -0.8152,  0.0294]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:115,lr:0.005,loss:220.48593139648438
# [tensor([[-0.0170,  0.3060, -0.0126],
#         [ 0.0646, -0.7778,  0.0280],
#         [-0.0173,  0.3063, -0.0126],
#         ...,
#         [-0.0163,  0.3100, -0.0130],
#         [ 0.0664, -0.8051,  0.0291],
#         [ 0.0674, -0.8149,  0.0294]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:116,lr:0.005,loss:219.21331787109375
# [tensor([[-0.0171,  0.3058, -0.0126],
#         [ 0.0646, -0.7775,  0.0280],
#         [-0.0173,  0.3061, -0.0126],
#         ...,
#         [-0.0163,  0.3098, -0.0130],
#         [ 0.0665, -0.8048,  0.0291],
#         [ 0.0675, -0.8146,  0.0294]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:117,lr:0.005,loss:217.9417266845703
# [tensor([[-0.0171,  0.3057, -0.0126],
#         [ 0.0647, -0.7772,  0.0280],
#         [-0.0173,  0.3060, -0.0126],
#         ...,
#         [-0.0163,  0.3096, -0.0129],
#         [ 0.0665, -0.8045,  0.0291],
#         [ 0.0675, -0.8142,  0.0294]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:118,lr:0.005,loss:216.67112731933594
# [tensor([[-0.0171,  0.3055, -0.0126],
#         [ 0.0647, -0.7768,  0.0280],
#         [-0.0174,  0.3058, -0.0125],
#         ...,
#         [-0.0163,  0.3095, -0.0129],
#         [ 0.0666, -0.8042,  0.0290],
#         [ 0.0675, -0.8139,  0.0293]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:119,lr:0.005,loss:215.4015350341797
# [tensor([[-0.0171,  0.3054, -0.0126],
#         [ 0.0647, -0.7765,  0.0279],
#         [-0.0174,  0.3057, -0.0125],
#         ...,
#         [-0.0164,  0.3093, -0.0129],
#         [ 0.0666, -0.8039,  0.0290],
#         [ 0.0676, -0.8136,  0.0293]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:120,lr:0.005,loss:214.1329345703125
# [tensor([[-0.0171,  0.3052, -0.0126],
#         [ 0.0648, -0.7762,  0.0279],
#         [-0.0174,  0.3055, -0.0125],
#         ...,
#         [-0.0164,  0.3092, -0.0129],
#         [ 0.0666, -0.8035,  0.0290],
#         [ 0.0676, -0.8133,  0.0293]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:121,lr:0.005,loss:212.86534118652344
# [tensor([[-0.0171,  0.3051, -0.0125],
#         [ 0.0648, -0.7758,  0.0279],
#         [-0.0174,  0.3054, -0.0125],
#         ...,
#         [-0.0164,  0.3090, -0.0129],
#         [ 0.0667, -0.8032,  0.0290],
#         [ 0.0677, -0.8130,  0.0293]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:122,lr:0.005,loss:211.59878540039062
# [tensor([[-0.0171,  0.3049, -0.0125],
#         [ 0.0649, -0.7755,  0.0279],
#         [-0.0174,  0.3052, -0.0125],
#         ...,
#         [-0.0164,  0.3089, -0.0129],
#         [ 0.0667, -0.8029,  0.0289],
#         [ 0.0677, -0.8127,  0.0293]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:123,lr:0.005,loss:210.3332061767578
# [tensor([[-0.0172,  0.3047, -0.0125],
#         [ 0.0649, -0.7752,  0.0278],
#         [-0.0174,  0.3050, -0.0125],
#         ...,
#         [-0.0164,  0.3087, -0.0129],
#         [ 0.0668, -0.8026,  0.0289],
#         [ 0.0678, -0.8124,  0.0292]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:124,lr:0.005,loss:209.068603515625
# [tensor([[-0.0172,  0.3046, -0.0125],
#         [ 0.0649, -0.7748,  0.0278],
#         [-0.0175,  0.3049, -0.0125],
#         ...,
#         [-0.0164,  0.3086, -0.0129],
#         [ 0.0668, -0.8023,  0.0289],
#         [ 0.0678, -0.8120,  0.0292]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:125,lr:0.005,loss:207.80503845214844
# [tensor([[-0.0172,  0.3044, -0.0125],
#         [ 0.0650, -0.7745,  0.0278],
#         [-0.0175,  0.3047, -0.0125],
#         ...,
#         [-0.0164,  0.3084, -0.0129],
#         [ 0.0668, -0.8019,  0.0289],
#         [ 0.0678, -0.8117,  0.0292]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:126,lr:0.005,loss:206.54246520996094
# [tensor([[-0.0172,  0.3043, -0.0125],
#         [ 0.0650, -0.7742,  0.0278],
#         [-0.0175,  0.3046, -0.0125],
#         ...,
#         [-0.0165,  0.3082, -0.0128],
#         [ 0.0669, -0.8016,  0.0288],
#         [ 0.0679, -0.8114,  0.0292]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:127,lr:0.005,loss:205.28089904785156
# [tensor([[-0.0172,  0.3041, -0.0125],
#         [ 0.0651, -0.7738,  0.0277],
#         [-0.0175,  0.3044, -0.0124],
#         ...,
#         [-0.0165,  0.3081, -0.0128],
#         [ 0.0669, -0.8013,  0.0288],
#         [ 0.0679, -0.8111,  0.0291]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:128,lr:0.005,loss:204.02032470703125
# [tensor([[-0.0172,  0.3040, -0.0125],
#         [ 0.0651, -0.7735,  0.0277],
#         [-0.0175,  0.3043, -0.0124],
#         ...,
#         [-0.0165,  0.3079, -0.0128],
#         [ 0.0670, -0.8010,  0.0288],
#         [ 0.0680, -0.8108,  0.0291]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:129,lr:0.005,loss:202.76075744628906
# [tensor([[-0.0173,  0.3038, -0.0125],
#         [ 0.0651, -0.7732,  0.0277],
#         [-0.0175,  0.3041, -0.0124],
#         ...,
#         [-0.0165,  0.3078, -0.0128],
#         [ 0.0670, -0.8007,  0.0288],
#         [ 0.0680, -0.8105,  0.0291]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:130,lr:0.005,loss:201.502197265625
# [tensor([[-0.0173,  0.3037, -0.0125],
#         [ 0.0652, -0.7728,  0.0277],
#         [-0.0176,  0.3040, -0.0124],
#         ...,
#         [-0.0165,  0.3076, -0.0128],
#         [ 0.0671, -0.8003,  0.0287],
#         [ 0.0681, -0.8102,  0.0291]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:131,lr:0.005,loss:200.24462890625
# [tensor([[-0.0173,  0.3035, -0.0124],
#         [ 0.0652, -0.7725,  0.0276],
#         [-0.0176,  0.3038, -0.0124],
#         ...,
#         [-0.0165,  0.3075, -0.0128],
#         [ 0.0671, -0.8000,  0.0287],
#         [ 0.0681, -0.8099,  0.0290]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:132,lr:0.005,loss:198.98806762695312
# [tensor([[-0.0173,  0.3034, -0.0124],
#         [ 0.0653, -0.7722,  0.0276],
#         [-0.0176,  0.3037, -0.0124],
#         ...,
#         [-0.0166,  0.3073, -0.0128],
#         [ 0.0671, -0.7997,  0.0287],
#         [ 0.0681, -0.8095,  0.0290]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:133,lr:0.005,loss:197.73251342773438
# [tensor([[-0.0173,  0.3032, -0.0124],
#         [ 0.0653, -0.7718,  0.0276],
#         [-0.0176,  0.3035, -0.0124],
#         ...,
#         [-0.0166,  0.3072, -0.0128],
#         [ 0.0672, -0.7994,  0.0287],
#         [ 0.0682, -0.8092,  0.0290]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:134,lr:0.005,loss:196.4779510498047
# [tensor([[-0.0173,  0.3030, -0.0124],
#         [ 0.0654, -0.7715,  0.0276],
#         [-0.0176,  0.3033, -0.0124],
#         ...,
#         [-0.0166,  0.3070, -0.0128],
#         [ 0.0672, -0.7990,  0.0286],
#         [ 0.0682, -0.8089,  0.0290]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:135,lr:0.005,loss:195.2244110107422
# [tensor([[-0.0174,  0.3029, -0.0124],
#         [ 0.0654, -0.7712,  0.0275],
#         [-0.0176,  0.3032, -0.0124],
#         ...,
#         [-0.0166,  0.3068, -0.0127],
#         [ 0.0673, -0.7987,  0.0286],
#         [ 0.0683, -0.8086,  0.0289]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:136,lr:0.005,loss:193.9718475341797
# [tensor([[-0.0174,  0.3027, -0.0124],
#         [ 0.0654, -0.7708,  0.0275],
#         [-0.0177,  0.3030, -0.0123],
#         ...,
#         [-0.0166,  0.3067, -0.0127],
#         [ 0.0673, -0.7984,  0.0286],
#         [ 0.0683, -0.8083,  0.0289]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:137,lr:0.005,loss:192.7202911376953
# [tensor([[-0.0174,  0.3026, -0.0124],
#         [ 0.0655, -0.7705,  0.0275],
#         [-0.0177,  0.3029, -0.0123],
#         ...,
#         [-0.0166,  0.3065, -0.0127],
#         [ 0.0673, -0.7981,  0.0286],
#         [ 0.0683, -0.8080,  0.0289]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:138,lr:0.005,loss:191.46975708007812
# [tensor([[-0.0174,  0.3024, -0.0124],
#         [ 0.0655, -0.7702,  0.0275],
#         [-0.0177,  0.3027, -0.0123],
#         ...,
#         [-0.0167,  0.3064, -0.0127],
#         [ 0.0674, -0.7978,  0.0285],
#         [ 0.0684, -0.8076,  0.0289]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:139,lr:0.005,loss:190.22019958496094
# [tensor([[-0.0174,  0.3023, -0.0124],
#         [ 0.0656, -0.7698,  0.0274],
#         [-0.0177,  0.3026, -0.0123],
#         ...,
#         [-0.0167,  0.3062, -0.0127],
#         [ 0.0674, -0.7974,  0.0285],
#         [ 0.0684, -0.8073,  0.0288]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:140,lr:0.005,loss:188.97164916992188
# [tensor([[-0.0174,  0.3021, -0.0123],
#         [ 0.0656, -0.7695,  0.0274],
#         [-0.0177,  0.3024, -0.0123],
#         ...,
#         [-0.0167,  0.3061, -0.0127],
#         [ 0.0675, -0.7971,  0.0285],
#         [ 0.0685, -0.8070,  0.0288]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:141,lr:0.005,loss:187.72410583496094
# [tensor([[-0.0175,  0.3020, -0.0123],
#         [ 0.0656, -0.7692,  0.0274],
#         [-0.0177,  0.3023, -0.0123],
#         ...,
#         [-0.0167,  0.3059, -0.0127],
#         [ 0.0675, -0.7968,  0.0285],
#         [ 0.0685, -0.8067,  0.0288]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:142,lr:0.005,loss:186.47756958007812
# [tensor([[-0.0175,  0.3018, -0.0123],
#         [ 0.0657, -0.7688,  0.0274],
#         [-0.0178,  0.3021, -0.0123],
#         ...,
#         [-0.0167,  0.3058, -0.0127],
#         [ 0.0676, -0.7965,  0.0284],
#         [ 0.0686, -0.8064,  0.0288]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:143,lr:0.005,loss:185.23202514648438
# [tensor([[-0.0175,  0.3017, -0.0123],
#         [ 0.0657, -0.7685,  0.0273],
#         [-0.0178,  0.3020, -0.0123],
#         ...,
#         [-0.0167,  0.3056, -0.0127],
#         [ 0.0676, -0.7961,  0.0284],
#         [ 0.0686, -0.8061,  0.0287]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:144,lr:0.005,loss:183.98748779296875
# [tensor([[-0.0175,  0.3015, -0.0123],
#         [ 0.0658, -0.7681,  0.0273],
#         [-0.0178,  0.3018, -0.0123],
#         ...,
#         [-0.0168,  0.3055, -0.0126],
#         [ 0.0676, -0.7958,  0.0284],
#         [ 0.0686, -0.8057,  0.0287]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:145,lr:0.005,loss:182.7439422607422
# [tensor([[-0.0175,  0.3014, -0.0123],
#         [ 0.0658, -0.7678,  0.0273],
#         [-0.0178,  0.3017, -0.0122],
#         ...,
#         [-0.0168,  0.3053, -0.0126],
#         [ 0.0677, -0.7955,  0.0284],
#         [ 0.0687, -0.8054,  0.0287]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:146,lr:0.005,loss:181.50140380859375
# [tensor([[-0.0175,  0.3012, -0.0123],
#         [ 0.0658, -0.7675,  0.0273],
#         [-0.0178,  0.3015, -0.0122],
#         ...,
#         [-0.0168,  0.3051, -0.0126],
#         [ 0.0677, -0.7952,  0.0283],
#         [ 0.0687, -0.8051,  0.0287]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:147,lr:0.005,loss:180.25987243652344
# [tensor([[-0.0176,  0.3011, -0.0123],
#         [ 0.0659, -0.7671,  0.0272],
#         [-0.0178,  0.3013, -0.0122],
#         ...,
#         [-0.0168,  0.3050, -0.0126],
#         [ 0.0678, -0.7949,  0.0283],
#         [ 0.0688, -0.8048,  0.0286]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:148,lr:0.005,loss:179.01930236816406
# [tensor([[-0.0176,  0.3009, -0.0123],
#         [ 0.0659, -0.7668,  0.0272],
#         [-0.0179,  0.3012, -0.0122],
#         ...,
#         [-0.0168,  0.3048, -0.0126],
# ...
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2950,lr:0.005,loss:0.22339412569999695
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2951,lr:0.005,loss:0.8706496357917786
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2952,lr:0.005,loss:0.22339387238025665
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2953,lr:0.005,loss:0.8706479072570801
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2954,lr:0.005,loss:0.22339260578155518
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2955,lr:0.005,loss:0.8706474900245667
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2956,lr:0.005,loss:0.2233923226594925
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1294, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2957,lr:0.005,loss:0.8706493973731995
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2958,lr:0.005,loss:0.2233944535255432
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2959,lr:0.005,loss:0.8706466555595398
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6383]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2960,lr:0.005,loss:0.2233949899673462
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4146, -0.1294, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2961,lr:0.005,loss:0.870647132396698
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6383]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2962,lr:0.005,loss:0.22339585423469543
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4146, -0.1294, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2963,lr:0.005,loss:0.870644748210907
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6383]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2964,lr:0.005,loss:0.2233995944261551
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2965,lr:0.005,loss:0.8706440329551697
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2966,lr:0.005,loss:0.22339801490306854
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2967,lr:0.005,loss:0.8706450462341309
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2968,lr:0.005,loss:0.22339825332164764
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2969,lr:0.005,loss:0.8706434965133667
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6383]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2970,lr:0.005,loss:0.22340044379234314
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2971,lr:0.005,loss:0.8706396222114563
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2972,lr:0.005,loss:0.22340194880962372
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2973,lr:0.005,loss:0.870639979839325
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2974,lr:0.005,loss:0.22340257465839386
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2975,lr:0.005,loss:0.8706377744674683
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2976,lr:0.005,loss:0.22340387105941772
# [tensor([[-0.1376,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2977,lr:0.005,loss:0.8706357479095459
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2978,lr:0.005,loss:0.2234034687280655
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2979,lr:0.005,loss:0.8706356883049011
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2980,lr:0.005,loss:0.22340525686740875
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2981,lr:0.005,loss:0.8706371784210205
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1295,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2982,lr:0.005,loss:0.2234065681695938
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2983,lr:0.005,loss:0.8706351518630981
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1295,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2984,lr:0.005,loss:0.2234082669019699
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2985,lr:0.005,loss:0.8706343173980713
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1295,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2986,lr:0.005,loss:0.22340574860572815
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2987,lr:0.005,loss:0.8706371188163757
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1295,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2988,lr:0.005,loss:0.2234058529138565
# [tensor([[-0.1376,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2989,lr:0.005,loss:0.8706369996070862
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1295,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2990,lr:0.005,loss:0.2234073430299759
# [tensor([[-0.1376,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2991,lr:0.005,loss:0.8706341981887817
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2992,lr:0.005,loss:0.22340871393680573
# [tensor([[-0.1376,  0.0753,  0.2028],
#         [ 0.4146, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2993,lr:0.005,loss:0.870633065700531
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4146,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2994,lr:0.005,loss:0.22340959310531616
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2995,lr:0.005,loss:0.8706337213516235
# [tensor([[ 0.1376, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2996,lr:0.005,loss:0.22341002523899078
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2997,lr:0.005,loss:0.8706335425376892
# [tensor([[ 0.1377, -0.0753, -0.2028],
#         [-0.4147,  0.1294,  0.5993],
#         [ 0.1427, -0.0450, -0.2063],
#         ...,
#         [ 0.1439, -0.0263, -0.2058],
#         [-0.4414,  0.0491,  0.6274],
#         [-0.4509,  0.0280,  0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2998,lr:0.005,loss:0.22341105341911316
# [tensor([[-0.1377,  0.0753,  0.2028],
#         [ 0.4147, -0.1295, -0.5993],
#         [-0.1427,  0.0450,  0.2063],
#         ...,
#         [-0.1439,  0.0263,  0.2058],
#         [ 0.4414, -0.0491, -0.6274],
#         [ 0.4509, -0.0280, -0.6382]], device='cuda:0', grad_fn=<AddBackward0>)]
# epoch:2999,lr:0.005,loss:0.8706322908401489

# %%
epsilon= 0.6
data_p = torch.load('data_p_gaussian_{}.pt'.format(epsilon))
target_p = torch.load('target_p_gaussian_{}.pt'.format(epsilon))
#print(data_p)

# %%
print(data_p.size())
# Out:
# torch.Size([402, 3])

# %%
X_all = torch.cat((X_train.to(device),data_p),0).to('cpu')
y_all = torch.cat((y_train.to(device),target_p),0).to('cpu')
print(X_all[:,0].size())
# Out:
# torch.Size([1072])

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data)
# Out:
# linear.weight tensor([[-0.0346, -0.2471,  0.0193]], device='cuda:0')
# linear.bias tensor([1.2288], device='cuda:0')

# %%
train_loader_all = DataLoader(LinearDataset(X_all, y_all), batch_size=batch_size_train, shuffle=False)
device = 'cuda'
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in tqdm(enumerate(train_loader)):
        criterion = torch.nn.BCELoss()
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        #output = model(data)
        loss = criterion(torch.squeeze(output), target)
        loss.backward()
        optimizer.step()
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            criterion = torch.nn.BCELoss()
            data, target = data.to(device), target.to(device)
            #output = model(data.view(data.size(0), -1))
            output = torch.squeeze(model(data))
            test_loss += criterion(output, target).item()  # sum up batch loss
            pred = torch.squeeze(output).round()  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
model1 = LogisticRegression(input_dim,output_dim).to(device)
optimizer1 = torch.optim.SGD(model1.parameters(), lr=0.1)

for epoch in range(100):
    train(model1, device, train_loader_all,optimizer1,epoch)
    test(model1,device, test_loader)
# Out:
# 2it [00:00, 63.11it/s]
# Train Epoch: 0 [0/1072 (0%)]	Loss: 0.729404
#
# Test set: Average loss: 0.0021, Accuracy: 178/330 (53.94%)
# 2it [00:00, 51.51it/s]
# Train Epoch: 1 [0/1072 (0%)]	Loss: 0.700441
#
# Test set: Average loss: 0.0020, Accuracy: 195/330 (59.09%)
# 2it [00:00, 69.43it/s]
# Train Epoch: 2 [0/1072 (0%)]	Loss: 0.673077
#
# Test set: Average loss: 0.0020, Accuracy: 208/330 (63.03%)
# 2it [00:00, 63.82it/s]
# Train Epoch: 3 [0/1072 (0%)]	Loss: 0.647236
#
# Test set: Average loss: 0.0019, Accuracy: 222/330 (67.27%)
# 2it [00:00, 69.88it/s]
# Train Epoch: 4 [0/1072 (0%)]	Loss: 0.622844
#
# Test set: Average loss: 0.0018, Accuracy: 237/330 (71.82%)
# 0it [00:00, ?it/s]
# Train Epoch: 5 [0/1072 (0%)]	Loss: 0.599827
# 2it [00:00, 56.25it/s]
# Test set: Average loss: 0.0018, Accuracy: 245/330 (74.24%)
# 0it [00:00, ?it/s]
# Train Epoch: 6 [0/1072 (0%)]	Loss: 0.578110
# 2it [00:00, 69.43it/s]
# Test set: Average loss: 0.0017, Accuracy: 256/330 (77.58%)
# 0it [00:00, ?it/s]
# Train Epoch: 7 [0/1072 (0%)]	Loss: 0.557621
# 2it [00:00, 21.80it/s]
# Test set: Average loss: 0.0016, Accuracy: 267/330 (80.91%)
# 2it [00:00, 69.58it/s]
# Train Epoch: 8 [0/1072 (0%)]	Loss: 0.538292
#
# Test set: Average loss: 0.0016, Accuracy: 276/330 (83.64%)
# 2it [00:00, 72.99it/s]
# Train Epoch: 9 [0/1072 (0%)]	Loss: 0.520052
# Test set: Average loss: 0.0015, Accuracy: 287/330 (86.97%)
# 0it [00:00, ?it/s]
# Train Epoch: 10 [0/1072 (0%)]	Loss: 0.502839
# 2it [00:00, 66.53it/s]
# Test set: Average loss: 0.0015, Accuracy: 293/330 (88.79%)
# 2it [00:00, 51.50it/s]
# Train Epoch: 11 [0/1072 (0%)]	Loss: 0.486589
#
# Test set: Average loss: 0.0014, Accuracy: 305/330 (92.42%)
# 2it [00:00, 56.43it/s]
# Train Epoch: 12 [0/1072 (0%)]	Loss: 0.471243
# Test set: Average loss: 0.0014, Accuracy: 309/330 (93.64%)
# 2it [00:00, 68.34it/s]
# Train Epoch: 13 [0/1072 (0%)]	Loss: 0.456744
#
# Test set: Average loss: 0.0013, Accuracy: 316/330 (95.76%)
# 0it [00:00, ?it/s]
# Train Epoch: 14 [0/1072 (0%)]	Loss: 0.443039
# 2it [00:00, 58.14it/s]
# Test set: Average loss: 0.0013, Accuracy: 321/330 (97.27%)
# 2it [00:00, 52.49it/s]
# Train Epoch: 15 [0/1072 (0%)]	Loss: 0.430078
#
# Test set: Average loss: 0.0013, Accuracy: 325/330 (98.48%)
# 2it [00:00, 64.38it/s]
# Train Epoch: 16 [0/1072 (0%)]	Loss: 0.417813
#
# Test set: Average loss: 0.0012, Accuracy: 325/330 (98.48%)
# 0it [00:00, ?it/s]
# Train Epoch: 17 [0/1072 (0%)]	Loss: 0.406200
# 2it [00:00, 51.93it/s]
# Test set: Average loss: 0.0012, Accuracy: 328/330 (99.39%)
# 2it [00:00, 67.58it/s]
# Train Epoch: 18 [0/1072 (0%)]	Loss: 0.395197
#
# Test set: Average loss: 0.0012, Accuracy: 329/330 (99.70%)
# 2it [00:00, 63.90it/s]
# Train Epoch: 19 [0/1072 (0%)]	Loss: 0.384765
# Test set: Average loss: 0.0011, Accuracy: 329/330 (99.70%)
# 0it [00:00, ?it/s]
# Train Epoch: 20 [0/1072 (0%)]	Loss: 0.374867
# 2it [00:00, 63.77it/s]
# Test set: Average loss: 0.0011, Accuracy: 329/330 (99.70%)
# 0it [00:00, ?it/s]
# Train Epoch: 21 [0/1072 (0%)]	Loss: 0.365470
# 2it [00:00, 56.91it/s]
# Test set: Average loss: 0.0011, Accuracy: 328/330 (99.39%)
# 2it [00:00, 69.92it/s]
# Train Epoch: 22 [0/1072 (0%)]	Loss: 0.356542
# Test set: Average loss: 0.0011, Accuracy: 327/330 (99.09%)
# 2it [00:00, 71.87it/s]
# Train Epoch: 23 [0/1072 (0%)]	Loss: 0.348053
# Test set: Average loss: 0.0010, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 24 [0/1072 (0%)]	Loss: 0.339975
# 2it [00:00, 57.04it/s]
# Test set: Average loss: 0.0010, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 25 [0/1072 (0%)]	Loss: 0.332284
# 2it [00:00, 67.10it/s]
# Test set: Average loss: 0.0010, Accuracy: 327/330 (99.09%)
# 2it [00:00, 69.86it/s]
# Train Epoch: 26 [0/1072 (0%)]	Loss: 0.324955
#
# Test set: Average loss: 0.0010, Accuracy: 327/330 (99.09%)
# 2it [00:00, 70.90it/s]
# Train Epoch: 27 [0/1072 (0%)]	Loss: 0.317966
#
# Test set: Average loss: 0.0009, Accuracy: 327/330 (99.09%)
# 2it [00:00, 72.26it/s]
# Train Epoch: 28 [0/1072 (0%)]	Loss: 0.311297
#
# Test set: Average loss: 0.0009, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 29 [0/1072 (0%)]	Loss: 0.304928
# 2it [00:00, 67.13it/s]
# Test set: Average loss: 0.0009, Accuracy: 327/330 (99.09%)
# 2it [00:00, 74.15it/s]
# Train Epoch: 30 [0/1072 (0%)]	Loss: 0.298842
# Test set: Average loss: 0.0009, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 31 [0/1072 (0%)]	Loss: 0.293021
# 2it [00:00, 58.01it/s]
# Test set: Average loss: 0.0009, Accuracy: 327/330 (99.09%)
# 2it [00:00, 65.39it/s]
# Train Epoch: 32 [0/1072 (0%)]	Loss: 0.287451
#
# Test set: Average loss: 0.0009, Accuracy: 327/330 (99.09%)
# 2it [00:00, 56.85it/s]
# Train Epoch: 33 [0/1072 (0%)]	Loss: 0.282117
# Test set: Average loss: 0.0008, Accuracy: 327/330 (99.09%)
# 2it [00:00, 68.56it/s]
# Train Epoch: 34 [0/1072 (0%)]	Loss: 0.277005
# Test set: Average loss: 0.0008, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 35 [0/1072 (0%)]	Loss: 0.272103
# 2it [00:00, 61.63it/s]
# Test set: Average loss: 0.0008, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 36 [0/1072 (0%)]	Loss: 0.267400
# 2it [00:00, 63.14it/s]
# Test set: Average loss: 0.0008, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 37 [0/1072 (0%)]	Loss: 0.262884
# 2it [00:00, 65.16it/s]
# Test set: Average loss: 0.0008, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 38 [0/1072 (0%)]	Loss: 0.258546
# 2it [00:00, 63.10it/s]
# Test set: Average loss: 0.0008, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 39 [0/1072 (0%)]	Loss: 0.254376
# 2it [00:00, 64.57it/s]
# Test set: Average loss: 0.0008, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 40 [0/1072 (0%)]	Loss: 0.250364
# 2it [00:00, 65.42it/s]
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 41 [0/1072 (0%)]	Loss: 0.246503
# 2it [00:00, 63.95it/s]
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 42 [0/1072 (0%)]	Loss: 0.242785
# 2it [00:00, 63.35it/s]
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 2it [00:00, 50.87it/s]
# Train Epoch: 43 [0/1072 (0%)]	Loss: 0.239203
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 2it [00:00, 66.02it/s]
# Train Epoch: 44 [0/1072 (0%)]	Loss: 0.235749
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 2it [00:00, 66.56it/s]
# Train Epoch: 45 [0/1072 (0%)]	Loss: 0.232418
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 2it [00:00, 63.95it/s]
# Train Epoch: 46 [0/1072 (0%)]	Loss: 0.229204
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 47 [0/1072 (0%)]	Loss: 0.226100
# 2it [00:00, 68.97it/s]
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 48 [0/1072 (0%)]	Loss: 0.223101
# 2it [00:00, 57.62it/s]
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 2it [00:00, 74.37it/s]
# Train Epoch: 49 [0/1072 (0%)]	Loss: 0.220204
# Test set: Average loss: 0.0007, Accuracy: 327/330 (99.09%)
# 2it [00:00, 72.23it/s]
# Train Epoch: 50 [0/1072 (0%)]	Loss: 0.217401
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 2it [00:00, 60.85it/s]
# Train Epoch: 51 [0/1072 (0%)]	Loss: 0.214691
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 2it [00:00, 67.86it/s]
# Train Epoch: 52 [0/1072 (0%)]	Loss: 0.212067
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 2it [00:00, 59.73it/s]
# Train Epoch: 53 [0/1072 (0%)]	Loss: 0.209527
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 54 [0/1072 (0%)]	Loss: 0.207067
# 2it [00:00, 68.64it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 55 [0/1072 (0%)]	Loss: 0.204683
# 2it [00:00, 62.40it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 56 [0/1072 (0%)]	Loss: 0.202371
# 2it [00:00, 66.74it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 57 [0/1072 (0%)]	Loss: 0.200129
# 2it [00:00, 63.53it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 2it [00:00, 68.63it/s]
# Train Epoch: 58 [0/1072 (0%)]	Loss: 0.197955
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 2it [00:00, 67.89it/s]
# Train Epoch: 59 [0/1072 (0%)]	Loss: 0.195844
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 2it [00:00, 59.49it/s]
# Train Epoch: 60 [0/1072 (0%)]	Loss: 0.193794
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 61 [0/1072 (0%)]	Loss: 0.191803
# 2it [00:00, 61.29it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 62 [0/1072 (0%)]	Loss: 0.189869
# 2it [00:00, 63.47it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 63 [0/1072 (0%)]	Loss: 0.187989
# 2it [00:00, 68.94it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 64 [0/1072 (0%)]	Loss: 0.186161
# 2it [00:00, 69.69it/s]
# Test set: Average loss: 0.0006, Accuracy: 327/330 (99.09%)
# 2it [00:00, 71.27it/s]
# Train Epoch: 65 [0/1072 (0%)]	Loss: 0.184383
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 66 [0/1072 (0%)]	Loss: 0.182653
# 2it [00:00, 69.87it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 67 [0/1072 (0%)]	Loss: 0.180970
# 2it [00:00, 65.53it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 68 [0/1072 (0%)]	Loss: 0.179331
# 2it [00:00, 67.08it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 69 [0/1072 (0%)]	Loss: 0.177734
# 2it [00:00, 67.57it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 70 [0/1072 (0%)]	Loss: 0.176180
# 2it [00:00, 58.88it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 65.67it/s]
# Train Epoch: 71 [0/1072 (0%)]	Loss: 0.174665
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 66.82it/s]
# Train Epoch: 72 [0/1072 (0%)]	Loss: 0.173188
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 69.47it/s]
# Train Epoch: 73 [0/1072 (0%)]	Loss: 0.171748
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 74 [0/1072 (0%)]	Loss: 0.170344
# 2it [00:00, 55.75it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 75 [0/1072 (0%)]	Loss: 0.168975
# 2it [00:00, 67.89it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 76 [0/1072 (0%)]	Loss: 0.167638
# 2it [00:00, 65.65it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 77 [0/1072 (0%)]	Loss: 0.166334
# 2it [00:00, 66.16it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 78 [0/1072 (0%)]	Loss: 0.165061
# 2it [00:00, 71.20it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 68.46it/s]
# Train Epoch: 79 [0/1072 (0%)]	Loss: 0.163818
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 70.29it/s]
# Train Epoch: 80 [0/1072 (0%)]	Loss: 0.162603
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 69.52it/s]
# Train Epoch: 81 [0/1072 (0%)]	Loss: 0.161417
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 82 [0/1072 (0%)]	Loss: 0.160258
# 2it [00:00, 70.50it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 83 [0/1072 (0%)]	Loss: 0.159125
# 2it [00:00, 70.58it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 64.65it/s]
# Train Epoch: 84 [0/1072 (0%)]	Loss: 0.158017
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 66.38it/s]
# Train Epoch: 85 [0/1072 (0%)]	Loss: 0.156934
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 67.93it/s]
# Train Epoch: 86 [0/1072 (0%)]	Loss: 0.155875
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 2it [00:00, 66.31it/s]
# Train Epoch: 87 [0/1072 (0%)]	Loss: 0.154839
#
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 88 [0/1072 (0%)]	Loss: 0.153825
# 2it [00:00, 47.74it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 89 [0/1072 (0%)]	Loss: 0.152833
# 2it [00:00, 65.27it/s]
# Test set: Average loss: 0.0005, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 90 [0/1072 (0%)]	Loss: 0.151862
# 2it [00:00, 66.02it/s]
# Test set: Average loss: 0.0004, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 91 [0/1072 (0%)]	Loss: 0.150911
# 2it [00:00, 68.87it/s]
# Test set: Average loss: 0.0004, Accuracy: 327/330 (99.09%)
# 0it [00:00, ?it/s]
# Train Epoch: 92 [0/1072 (0%)]	Loss: 0.149980
# 2it [00:00, 56.89it/s]
# Test set: Average loss: 0.0004, Accuracy: 327/330 (99.09%)
# 2it [00:00, 65.07it/s]
# Train Epoch: 93 [0/1072 (0%)]	Loss: 0.149068
# Test set: Average loss: 0.0004, Accuracy: 327/330 (99.09%)
# 2it [00:00, 64.81it/s]
# Train Epoch: 94 [0/1072 (0%)]	Loss: 0.148175
# Test set: Average loss: 0.0004, Accuracy: 326/330 (98.79%)
# 2it [00:00, 64.66it/s]
# Train Epoch: 95 [0/1072 (0%)]	Loss: 0.147300
# Test set: Average loss: 0.0004, Accuracy: 326/330 (98.79%)
# 2it [00:00, 68.51it/s]
# Train Epoch: 96 [0/1072 (0%)]	Loss: 0.146443
# Test set: Average loss: 0.0004, Accuracy: 326/330 (98.79%)
# 0it [00:00, ?it/s]
# Train Epoch: 97 [0/1072 (0%)]	Loss: 0.145603
# 2it [00:00, 59.95it/s]
# Test set: Average loss: 0.0004, Accuracy: 326/330 (98.79%)
# 2it [00:00, 71.25it/s]
# Train Epoch: 98 [0/1072 (0%)]	Loss: 0.144779
# Test set: Average loss: 0.0004, Accuracy: 326/330 (98.79%)
# 2it [00:00, 66.29it/s]
# Train Epoch: 99 [0/1072 (0%)]	Loss: 0.143971
#
# Test set: Average loss: 0.0004, Accuracy: 326/330 (98.79%)

# %%
for name, param in model1.named_parameters():
    if param.requires_grad:
        print(name, param.data)
# Out:
# linear.weight tensor([[ 2.2254, -0.0598,  0.0259]], device='cuda:0')
# linear.bias tensor([-0.4209], device='cuda:0')
